# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data/cnae/2020/RAIS_vinculos_2020.csv')
m = df.pivot_table(index='Municipality ID', 
                      columns='Class ID', 
                      values='Workers', 
                      aggfunc='sum',  # Ensure summing workers
                      fill_value=0).values
 # Calculate totals
X = np.sum(m)          # Grand total
X_c = np.sum(m, axis=1, keepdims=True)  # Column sums (locations)
X_p = np.sum(m, axis=0, keepdims=True)  # Row sums (activities)

# Calculate Rcp with broadcasting and zero division handling
with np.errstate(divide='ignore', invalid='ignore'):
    R = (m * X) / (X_c * X_p)
    R[~np.isfinite(R)] = 0  # Replace inf/nan with 0

# Convert back to DataFrame
municipalities = df['Municipality ID'].unique()
classes = df['Class'].unique()

Rcp_df = pd.DataFrame(R, 
                     index=municipalities, 
                     columns=classes)

# %%
#Rcp_df.max().max()
# Display the first few rows to verify strucdf=ture
df=Rcp_df
print("RCA data:")
print(df.head())
print(f"Shape: {df.shape}")
print(f"Locality IDs: {df.index.tolist()[:5]}...")
print(f"Activity IDs: {df.columns.tolist()[:5]}...")

# Create binary matrix (1 if RCA >= 1, else 0)
binary_matrix = (df >= 1.0).astype(int)

print("\nBinary matrix:")
print(binary_matrix.head())
print(f"Binary matrix shape: {binary_matrix.shape}")

# Check some statistics
print(f"\nStatistics:")
print(f"Total entries: {binary_matrix.size}")
print(f"Ones (RCA >= 1): {binary_matrix.sum().sum()}")
print(f"Zeros (RCA < 1): {binary_matrix.size - binary_matrix.sum().sum()}")
print(f"Percentage with RCA >= 1: {binary_matrix.sum().sum()/binary_matrix.size*100:.2f}%")

# Calculate diversity and ubiquity (key metrics for economic complexity)
diversity = binary_matrix.sum(axis=1)  # Number of activities per location
ubiquity = binary_matrix.sum(axis=0)   # Number of locations per activity

print("\nDiversity (activities per location):")
print(diversity.head())

print("\nUbiquity (locations per activity):")
print(ubiquity.head())
# Out:
# RCA data:
#          Cultivo de cereais  \
# 1100015            0.175294
# 1100023            0.660811
# 1100031            3.834745
# 1100049            0.124683
# 1100056            2.565574
#
#          Cultivo de algodão herbáceo e de outras fibras de lavoura temporária  \
# 1100015                                           0.000000
# 1100023                                           0.650133
# 1100031                                           0.000000
# 1100049                                           0.000000
# 1100056                                           0.000000
#
#          Cultivo de cana-de-açúcar  Cultivo de fumo  Cultivo de soja  \
# 1100015                        0.0              0.0         0.741554
# 1100023                        0.0              0.0         0.381079
# 1100031                        0.0              0.0        38.062616
# 1100049                        0.0              0.0         0.000000
# 1100056                        0.0              0.0        19.515160
#
#          Cultivo de oleaginosas de lavoura temporária, exceto soja  \
# 1100015                                           0.000000
# 1100023                                           1.509467
# 1100031                                           0.000000
# 1100049                                           0.000000
# 1100056                                           0.000000
#
#          Cultivo de plantas de lavoura temporária não especificadas anteriormente  \
# 1100015                                           0.000000
# 1100023                                           0.000000
# 1100031                                           0.000000
# 1100049                                           0.207346
# 1100056                                           0.000000
#
#          Horticultura  Cultivo de flores e plantas ornamentais  \
# 1100015      0.000000                                 0.000000
# 1100023      0.000000                                 0.447921
# 1100031      0.000000                                 0.000000
# 1100049      0.229445                                 0.143674
# 1100056      0.000000                                 0.000000
#
#          Cultivo de laranja  ...  \
# 1100015            0.000000  ...
# 1100023            0.000000  ...
# 1100031            0.000000  ...
# 1100049            0.581585  ...
# 1100056            0.000000  ...
#
#          Reparação e manutenção de computadores e de equipamentos periféricos  \
# 1100015                                           0.000000
# 1100023                                           0.261485
# 1100031                                           0.000000
# 1100049                                           0.478078
# 1100056                                           2.071018
#
#          Reparação e manutenção de equipamentos de comunicação  \
# 1100015                                           0.000000
# 1100023                                           0.823749
# 1100031                                           0.000000
# 1100049                                           0.462392
# 1100056                                           0.000000
#
#          Reparação e manutenção de equipamentos eletroeletrônicos de uso pessoal e doméstico  \
# 1100015                                           0.000000
# 1100023                                           2.132325
# 1100031                                           0.000000
# 1100049                                           1.538911
# 1100056                                           0.000000
#
#          Reparação e manutenção de objetos e equipamentos pessoais e domésticos não especificados anteriormente  \
# 1100015                                           0.000000
# 1100023                                           0.504788
# 1100031                                           0.000000
# 1100049                                           0.839014
# 1100056                                           0.726916
#
#          Lavanderias, tinturarias e toalheiros  \
# 1100015                               0.000000
# 1100023                               0.415695
# 1100031                               0.000000
# 1100049                               0.240008
# 1100056                               0.000000
#
#          Cabeleireiros e outras atividades de tratamento de beleza  \
# 1100015                                           0.212685
# 1100023                                           1.121422
# 1100031                                           0.000000
# 1100049                                           1.764909
# 1100056                                           0.000000
#
#          Atividades funerárias e serviços relacionados  \
# 1100015                                       1.248872
# 1100023                                       0.533357
# 1100031                                       0.000000
# 1100049                                       2.013463
# 1100056                                       0.487420
#
#          Atividades de serviços pessoais não especificadas anteriormente  \
# 1100015                                           0.793106
# 1100023                                           0.527610
# 1100031                                           0.000000
# 1100049                                           1.551322
# 1100056                                           1.857239
#
#          Serviços domésticos  \
# 1100015                  0.0
# 1100023                  0.0
# 1100031                  0.0
# 1100049                  0.0
# 1100056                  0.0
#
#          Organismos internacionais e outras instituições extraterritoriais
# 1100015                                                0.0
# 1100023                                                0.0
# 1100031                                                0.0
# 1100049                                                0.0
# 1100056                                                0.0
#
# [5 rows x 671 columns]
# Shape: (5570, 671)
# Locality IDs: [1100015, 1100023, 1100031, 1100049, 1100056]...
# Activity IDs: ['Cultivo de cereais', 'Cultivo de algodão herbáceo e de outras fibras de lavoura temporária', 'Cultivo de cana-de-açúcar', 'Cultivo de fumo', 'Cultivo de soja']...
#
# Binary matrix:
#          Cultivo de cereais  \
# 1100015                   0
# 1100023                   0
# 1100031                   1
# 1100049                   0
# 1100056                   1
#
#          Cultivo de algodão herbáceo e de outras fibras de lavoura temporária  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
#          Cultivo de cana-de-açúcar  Cultivo de fumo  Cultivo de soja  \
# 1100015                          0                0                0
# 1100023                          0                0                0
# 1100031                          0                0                1
# 1100049                          0                0                0
# 1100056                          0                0                1
#
#          Cultivo de oleaginosas de lavoura temporária, exceto soja  \
# 1100015                                                  0
# 1100023                                                  1
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
#          Cultivo de plantas de lavoura temporária não especificadas anteriormente  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
#          Horticultura  Cultivo de flores e plantas ornamentais  \
# 1100015             0                                        0
# 1100023             0                                        0
# 1100031             0                                        0
# 1100049             0                                        0
# 1100056             0                                        0
#
#          Cultivo de laranja  ...  \
# 1100015                   0  ...
# 1100023                   0  ...
# 1100031                   0  ...
# 1100049                   0  ...
# 1100056                   0  ...
#
#          Reparação e manutenção de computadores e de equipamentos periféricos  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  1
#
#          Reparação e manutenção de equipamentos de comunicação  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
#          Reparação e manutenção de equipamentos eletroeletrônicos de uso pessoal e doméstico  \
# 1100015                                                  0
# 1100023                                                  1
# 1100031                                                  0
# 1100049                                                  1
# 1100056                                                  0
#
#          Reparação e manutenção de objetos e equipamentos pessoais e domésticos não especificados anteriormente  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
#          Lavanderias, tinturarias e toalheiros  \
# 1100015                                      0
# 1100023                                      0
# 1100031                                      0
# 1100049                                      0
# 1100056                                      0
#
#          Cabeleireiros e outras atividades de tratamento de beleza  \
# 1100015                                                  0
# 1100023                                                  1
# 1100031                                                  0
# 1100049                                                  1
# 1100056                                                  0
#
#          Atividades funerárias e serviços relacionados  \
# 1100015                                              1
# 1100023                                              0
# 1100031                                              0
# 1100049                                              1
# 1100056                                              0
#
#          Atividades de serviços pessoais não especificadas anteriormente  \
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  1
# 1100056                                                  1
#
#          Serviços domésticos  \
# 1100015                    0
# 1100023                    0
# 1100031                    0
# 1100049                    0
# 1100056                    0
#
#          Organismos internacionais e outras instituições extraterritoriais
# 1100015                                                  0
# 1100023                                                  0
# 1100031                                                  0
# 1100049                                                  0
# 1100056                                                  0
#
# [5 rows x 671 columns]
# Binary matrix shape: (5570, 671)
#
# Statistics:
# Total entries: 3737470
# Ones (RCA >= 1): 230747
# Zeros (RCA < 1): 3506723
# Percentage with RCA >= 1: 6.17%
#
# Diversity (activities per location):
# 1100015     66
# 1100023    145
# 1100031     27
# 1100049    141
# 1100056     73
# dtype: int64
#
# Ubiquity (locations per activity):
# Cultivo de cereais                                                      1512
# Cultivo de algodão herbáceo e de outras fibras de lavoura temporária     361
# Cultivo de cana-de-açúcar                                                655
# Cultivo de fumo                                                           41
# Cultivo de soja                                                         1079
# dtype: int64

# %%
binary_matrix.loc[3550308].sum()
# Out:
# 43
